# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import sleep

# %%
 
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"}

# %%
html = requests.get('https://www.99.co/singapore/commercial/rent?property_segments=commercial&main_category=retail%2Coffice%2Cshophouse',headers= headers )

# %%
html
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(html.text,"lxml")

# %%
property_list  = soup.find('div',class_ = "_31ajL listingsList").find_all('div',class_="_2J3pS _3AXiL")

# %%
property_list
# Out:
# [<div class="_2J3pS _3AXiL"><div class="_2fomV"><div class="_3RSyE"><div class="slick-slider _3qay1 slick-initialized" dir="ltr"><span class="slick-arrow slick-prev" style="display:block"><div class="_1pXuj _1IapJ nowmz"><div><svg fill="none" height="28" viewbox="0 0 17 28" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M13.32 27.33c.36.34.8.53 1.3.53 1.04 0 1.85-.81 1.85-1.85 0-.51-.2-.98-.56-1.34L4.97 13.98 15.91 3.33c.36-.36.56-.85.56-1.35 0-1.03-.8-1.84-1.86-1.84-.5 0-.93.19-1.28.53L1.18 12.55c-.44.4-.66.9-.66 1.45 0 .55.22 1.01.64 1.44l12.16 11.89z" fill="#fff"></path></svg></div></div></span><div class="slick-list"><div class="slick-track" style="width:1100%;left:-100%"><div aria-hidden="true" class="slick-slide slick-cloned" data-index="-1" style="width:9.090909090909092%" tabindex="-1"></div><div aria-hidden="false" class="slick-slide slick-active slick-current" data-index="0" style="outline:none;width:9.090909090909092%" tabindex="-1"><div><div class="_3jfDu"><div cl
# ...

# %%
with open("Renting Commercial Properties in Singapore2.csv",'w',newline='') as file:
    writer = csv.writer(file)
    headers = ["Address","Property_Type","Property_size","Renting_Price","Uploaded_Time"]
    writer.writerow(headers)
    for property_ in property_list:
        Address = property_.find("p",class_="dniCg _3WG9R _2rhE- _1c-pJ").text.strip()
        Property_Type = property_.find("p",class_="dniCg _1LPAx _2rhE- _1c-pJ").text.strip()
        Property_size = property_.find("p",class_="dniCg _2rhE- _1c-pJ").text.strip()
        Renting_Price =  property_.find("p",class_="_2sIc2 JlU_W _2rhE-").text.strip()
        Uploaded_Time =  property_.find("p",class_="_2y86Q _1dAt8 _2rhE-").text.strip()

        print(Address + " " +Property_Type + " " +Property_size+ " " + Renting_Price + " "+ Uploaded_Time)
        writer.writerow([Address.encode("utf-8"),Property_Type.encode("utf-8"),Property_size.encode("utf-8"),
                         Renting_Price.encode("utf-8"),Uploaded_Time.encode("utf-8")])
file.close()
# Out:
# 39 Hongkong St · D1 Office, Others 937 sqft / 87.05 sqm $7,200/mo Updated 15 min ago
# 735 Pasir Ris St 72 · D18 Retail, Shop 350 sqft / 32.52 sqm $3,400/mo Updated 29 min ago
# 55 Changi Rd · D14 Retail, Others 183 sqft / 17 sqm $1,500/mo Updated 37 min ago
# 100 Peck Seah St · D2 Office, Grade A 517 sqft / 48.03 sqm $3,500/mo Updated 1 hr ago
# 19 Keppel Rd · D2 Office, Grade A 650 sqft / 60.39 sqm $3,770/mo Updated 1 hr ago
# 198 Sth Bridge Rd · D1 Shophouse 4,072 sqft / 378.3 sqm $42,000/mo Updated 1 hr ago
# 19 Keppel Rd · D2 Office, Grade A 3,600 sqft / 334.45 sqm $20,880/mo Updated 1 hr ago
# 24 Raffles Pl · D1 Retail, Shop 666 sqft / 61.87 sqm $7,500/mo Updated 1 hr ago
# 978 Upp Serangoon Rd · D19 Retail, Shop 517 sqft / 48.03 sqm $7,300/mo Updated 1 hr ago
# · D10 Retail, Others 1,100 sqft / 102.19 sqm $5,300/mo Updated 1 hr ago
# 2 Venture Dr · D22 Office, Grade A 764 sqft / 70.98 sqm $2,950/mo Updated 2 hrs ago
# ...
